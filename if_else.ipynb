# %%
sal = int(input('Enter sal '))
exp = int(input('Enter a exp '))

if exp == 10 :
  bonus = sal * 20 /100
  print("SAL : ",sal + bonus)
elif exp == 5 :
  bonus = sal * 10 /100
  print('SAL : ',sal + bonus)
else :
  print('No bonus')
# Out:
# Enter sal 1038376
# Enter a exp 5
# SAL :  1142213.6

# %%
x = int(input('Enter x '))
y = int(input('Enter y '))

if x > 0 and y > 0 :
  print('Qudrant 1')
elif x < 0 and y > 0 :
  print('Quadrant 2')
elif x < 0 and y < 0 :
  print('Quadrat 3 ')
elif x > 0 and y < 0 :
  print('Quadrant 4')
else :
  print('Origin3')
# Out:
# Enter x -6
# Enter y 1
# Quadrant 2

# %%
unit = int(input('Enter unit '))

if unit <= 100 :
  print(f'Bill : {unit * 2} Rs.')
elif unit <= 300 :
  print(f'Bill : {unit * 4} Rs.')
else :
  print(f'Bill : {unit * 9} Rs.')
# Out:
# Enter unit 295
# Bill : 1180 Rs.
